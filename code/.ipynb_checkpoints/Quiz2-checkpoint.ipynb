# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot
import numpy

# %precision 3
# %matplotlib inline

# %%
sin_sig = thinkdsp.SinSignal(freq=60)
sinwave = sin_sig.make_wave(duration=1, framerate=100)
sinwave.plot()
