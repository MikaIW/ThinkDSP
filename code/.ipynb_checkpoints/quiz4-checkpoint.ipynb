# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot
import thinkstats2
import math
import numpy
import pandas 

# %precision 3
# %matplotlib inline

PI2 = 2 * math.pi
i = complex(0, 1)

# %%
thinkdsp.ComplexSinusoid(freq=440,offset=1.1,amp=0.7)

# %%
sin = thinkdsp.ComplexSinusoid(freq=440,offset=-1.72,amp=1.1063)
sin.plot()
evaluate(sin.hs(2.1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-7a6010da7f90> in <module>()
#       1 sin = thinkdsp.ComplexSinusoid(freq=440,offset=-1.72,amp=1.1063)
#       2 sin.plot()
# ----> 3 evaluate(sin.hs(2.1))
#
# NameError: name 'evaluate' is not defined

# %%
help thinkdsp.ComplexSinusoid
# Out:
#   File "<ipython-input-11-1a017dbab466>", line 1
#     help thinkdsp.ComplexSinusoid
#                 ^
# SyntaxError: invalid syntax
